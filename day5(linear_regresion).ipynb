# %% [markdown]
# **linear regresion**

# %%
# y= mx+b
# m is slope
# b = y intercept
# ex: y = 2x+1  (x=1) ... y=3


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

dataset = pd.read_csv('student_scores.csv')
dataset
# Out:
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %%
dataset.plot(x='Hours',y='Scores', style='^')
plt.title('Hours vs Percentage')
plt.xlabel('Hours')
plt.ylabel('Percentage')
plt.show()

# %%
x=dataset.iloc[:,:-1].values
y=dataset.iloc[:,1].values
print(x)
print(y)
# Out:
# [[2.5]
#  [5.1]
#  [3.2]
#  [8.5]
#  [3.5]
#  [1.5]
#  [9.2]
#  [5.5]
#  [8.3]
#  [2.7]
#  [7.7]
#  [5.9]
#  [4.5]
#  [3.3]
#  [1.1]
#  [8.9]
#  [2.5]
#  [1.9]
#  [6.1]
#  [7.4]
#  [2.7]
#  [4.8]
#  [3.8]
#  [6.9]
#  [7.8]]
# [21 47 27 75 30 20 88 60 81 25 85 62 41 42 17 95 30 24 67 69 30 54 35 76
#  86]

# %%
from  sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)
print('training data',x_train)
print('testing data ',x_test)
print('training data y',y_train)
print('testing data y',y_test)
# Out:
# training data [[6.1]
#  [7.4]
#  [1.9]
#  [8.5]
#  [3.8]
#  [3.3]
#  [4.5]
#  [3.2]
#  [2.7]
#  [6.9]
#  [7.7]
#  [5.9]
#  [3.5]
#  [2.5]
#  [7.8]
#  [1.5]
#  [8.9]
#  [5.5]
#  [9.2]
#  [8.3]]
# testing data  [[5.1]
#  [2.7]
#  [2.5]
#  [1.1]
#  [4.8]]
# training data y [67 69 24 75 35 42 41 27 25 76 85 62 30 21 86 20 95 60 88 81]
# testing data y [47 30 30 17 54]

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train,y_train)

LinearRegression()

print(regressor.intercept_)
# Out:
# 0.7967884216087526

# %%
print(regressor.coef_)
# Out:
# [10.01892055]

# %%
y_pred = regressor.predict(x_test)
print(y_pred)
# Out:
# [51.89328321 27.8478739  25.84408979 11.81760102 48.88760704]

# %%
from sklearn import metrics
from sklearn.metrics import mean_squared_error,r2_score
print('Mean squarred Error:', mean_squared_error(y_test,y_pred))
print('root mean squarred error:', np.sqrt(mean_squared_error(y_test,y_pred)))
print('r_2  stastistic: %.2f' % r2_score(y_test,y_pred))
# Out:
# Mean squarred Error: 19.76825558488424
# root mean squarred error: 4.446150648019502
# r_2  stastistic: 0.89
